# %% [markdown]
# # ORI-C — Vivant : benchmark D’Onofrio
# Réexécute l’analyse rétrospective depuis les données versionnées. Le jeu était public avant l’analyse ORI-C.

# %%
from pathlib import Path
import importlib.util
ROOT=Path.cwd()
if not (ROOT/'03_branche_vivant').exists(): ROOT=ROOT.parent
p=ROOT/'03_branche_vivant/benchmark_histoire_antibiotique_2026/analyser.py'
spec=importlib.util.spec_from_file_location('dono',p)
m=importlib.util.module_from_spec(spec); spec.loader.exec_module(m)
r=m.main()
{k:r[k] for k in ['rmse_state_only','rmse_state_plus_history','same_complexity_shuffled_history_rmse_mean','permutation_p_history_better_than_shuffled','verdict']}
