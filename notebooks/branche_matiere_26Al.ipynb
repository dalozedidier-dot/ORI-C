# %% [markdown]
# # ORI-C — branche Matière : trace 26Al
# Lecture courte d’une table d’autorité déjà produite. Ce notebook ne transforme pas cette analyse rétrospective en preuve prospective.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
ROOT=Path.cwd()
if not (ROOT/'01_branche_matiere').exists():
    ROOT=ROOT.parent
p=ROOT/'01_branche_matiere/genealogie_cosmique_quantitative/INVENTAIRE_26AL_PAR_EVENEMENT.csv'
df=pd.read_csv(p)
df.head()

# %%
print(df.columns.tolist())
df

# %%
num=[c for c in df.columns if 'fraction' in c.lower() or '26al' in c.lower()]
print('Colonnes candidates:',num)
# La table complète reste visible ci-dessus ; aucune colonne n'est renommée pour éviter de masquer sa sémantique.
